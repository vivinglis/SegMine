# %% [markdown]
# # SegMine Task - Phenaros
# *Viv Inglis* \
# *2024-MAY-05*

# %% [markdown]
# The instructions are to do the following:
# - Segment the cells into single-cell masks
# - Harvest the cells - extract morphological information
# - Calculate the location of each cell
# - Mine profiles for each cell
# - Aggregate the data as either the Mean or Median of each unique well-site combo
# - Cluster the data using either UMAP or TSNE

# %% [markdown]
# ## Segmenting the Cells using Cellpose

# %%
# !pip install cellpose

# %% [markdown]
# I struggled a bit with installing the dependencies for Cellpose, and spent far too long trying to install the gui, but eventually succeeded after a hefty amount of googling, lots of StackOverflow, and a bit of ChatGPT help. Also I had tried to install DeepProfile prior to Cellpose, but found out that they require different versions of certain packages, so had to uninstall and start again. All this on an internet speed of roughly 8Mbps down since I wasn't at home on Saturday. Luckily, I returned that evening to a glorious ~200Mbps down and finally managed to download the image data files.

# %%
# !python3.8 -m cellpose --dir /home/vivinglis/phenaros/data/images --verbose --pretrained_model nuclei --diameter 0. --save_png --savedir /home/vivinglis/phenaros/cellpose_output/images
# Out:
# 2024-05-05 05:13:23,623 [INFO] WRITING LOG OUTPUT TO /home/vivinglis/.cellpose/run.log
# 2024-05-05 05:13:23,623 [INFO]
# cellpose version: 	3.0.7
# platform:       	linux
# python version: 	3.8.10
# torch version:  	2.3.0+cu121
# 2024-05-05 05:13:23,623 [INFO] >>>> using CPU
# 2024-05-05 05:13:23,772 [INFO] >>>> running cellpose on 3080 images using chan_to_seg GRAY and chan (opt) NONE
# 2024-05-05 05:13:23,772 [INFO] >>>> using CPU
# 2024-05-05 05:13:23,772 [INFO] >> nuclei << model set to be used
# 2024-05-05 05:13:23,926 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2024-05-05 05:13:23,927 [INFO] >>>> estimating diameter for each image
# 2024-05-05 05:13:23,936 [INFO] 0%|          | 0/3080 [00:00<?, ?it/s]
# 2024-05-05 05:13:23,943 [INFO] channels set to [0, 0]
# 2024-05-05 05:13:23,943 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:13:59,359 [INFO] estimated cell diameter(s) in 35.42 sec
# 2024-05-05 05:13:59,359 [INFO] >>> diameter(s) =
# 2024-05-05 05:13:59,359 [INFO] [ 59.88 ]
# 2024-05-05 05:13:59,359 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:14:23,838 [INFO] >>>> TOTAL TIME 59.90 sec
# 2024-05-05 05:14:24,172 [INFO] 0%|          | 1/3080 [01:00<51:31:03, 60.23s/it]
# 2024-05-05 05:14:24,186 [INFO] channels set to [0, 0]
# 2024-05-05 05:14:24,186 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:15:19,306 [INFO] estimated cell diameter(s) in 55.12 sec
# 2024-05-05 05:15:19,307 [INFO] >>> diameter(s) =
# 2024-05-05 05:15:19,307 [INFO] [ 14.45 ]
# 2024-05-05 05:15:19,307 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:16:18,221 [INFO] >>>> TOTAL TIME 114.03 sec
# 2024-05-05 05:16:18,640 [INFO] 0%|          | 2/3080 [02:54<78:46:38, 92.14s/it]
# 2024-05-05 05:16:18,661 [INFO] channels set to [0, 0]
# 2024-05-05 05:16:18,662 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:17:23,044 [INFO] estimated cell diameter(s) in 64.38 sec
# 2024-05-05 05:17:23,045 [INFO] >>> diameter(s) =
# 2024-05-05 05:17:23,045 [INFO] [ 16.89 ]
# 2024-05-05 05:17:23,045 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:18:14,489 [INFO] >>>> TOTAL TIME 115.83 sec
# 2024-05-05 05:18:14,787 [INFO] 0%|          | 3/3080 [04:50<88:07:19, 103.10s/it]
# 2024-05-05 05:18:14,802 [INFO] channels set to [0, 0]
# 2024-05-05 05:18:14,802 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:20:34,192 [INFO] estimated cell diameter(s) in 139.39 sec
# 2024-05-05 05:20:34,192 [INFO] >>> diameter(s) =
# 2024-05-05 05:20:34,192 [INFO] [ 6.96 ]
# 2024-05-05 05:20:34,192 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:24:26,352 [INFO] >>>> TOTAL TIME 371.55 sec
# 2024-05-05 05:24:26,711 [INFO] 0%|          | 4/3080 [11:02<178:46:28, 209.23s/it]
# 2024-05-05 05:24:26,730 [INFO] channels set to [0, 0]
# 2024-05-05 05:24:26,730 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:25:02,015 [INFO] estimated cell diameter(s) in 35.29 sec
# 2024-05-05 05:25:02,015 [INFO] >>> diameter(s) =
# 2024-05-05 05:25:02,015 [INFO] [ 36.25 ]
# 2024-05-05 05:25:02,015 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:25:22,618 [INFO] >>>> TOTAL TIME 55.89 sec
# 2024-05-05 05:25:22,937 [INFO] 0%|          | 5/3080 [11:58<131:35:18, 154.05s/it]
# 2024-05-05 05:25:22,951 [INFO] channels set to [0, 0]
# 2024-05-05 05:25:22,952 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:25:57,139 [INFO] estimated cell diameter(s) in 34.19 sec
# 2024-05-05 05:25:57,139 [INFO] >>> diameter(s) =
# 2024-05-05 05:25:57,140 [INFO] [ 58.16 ]
# 2024-05-05 05:25:57,140 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:26:17,182 [INFO] >>>> TOTAL TIME 54.23 sec
# 2024-05-05 05:26:17,474 [INFO] 0%|          | 6/3080 [12:53<102:39:13, 120.22s/it]
# 2024-05-05 05:26:17,500 [INFO] channels set to [0, 0]
# 2024-05-05 05:26:17,500 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:27:14,931 [INFO] estimated cell diameter(s) in 57.43 sec
# 2024-05-05 05:27:14,932 [INFO] >>> diameter(s) =
# 2024-05-05 05:27:14,932 [INFO] [ 13.63 ]
# 2024-05-05 05:27:14,933 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:28:36,007 [INFO] >>>> TOTAL TIME 138.51 sec
# 2024-05-05 05:28:36,328 [INFO] 0%|          | 7/3080 [15:12<107:49:13, 126.31s/it]
# 2024-05-05 05:28:36,344 [INFO] channels set to [0, 0]
# 2024-05-05 05:28:36,344 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:29:47,694 [INFO] estimated cell diameter(s) in 71.35 sec
# 2024-05-05 05:29:47,694 [INFO] >>> diameter(s) =
# 2024-05-05 05:29:47,694 [INFO] [ 16.14 ]
# 2024-05-05 05:29:47,694 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:30:52,795 [INFO] >>>> TOTAL TIME 136.45 sec
# 2024-05-05 05:30:53,121 [INFO] 0%|          | 8/3080 [17:29<110:37:58, 129.65s/it]
# 2024-05-05 05:30:53,141 [INFO] channels set to [0, 0]
# 2024-05-05 05:30:53,141 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:33:40,834 [INFO] estimated cell diameter(s) in 167.69 sec
# 2024-05-05 05:33:40,834 [INFO] >>> diameter(s) =
# 2024-05-05 05:33:40,834 [INFO] [ 4.92 ]
# 2024-05-05 05:33:40,834 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:41:20,874 [INFO] >>>> TOTAL TIME 627.73 sec
# 2024-05-05 05:41:21,231 [INFO] 0%|          | 9/3080 [27:57<243:31:32, 285.47s/it]
# 2024-05-05 05:41:21,245 [INFO] channels set to [0, 0]
# 2024-05-05 05:41:21,246 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:41:57,879 [INFO] estimated cell diameter(s) in 36.63 sec
# 2024-05-05 05:41:57,879 [INFO] >>> diameter(s) =
# 2024-05-05 05:41:57,879 [INFO] [ 28.25 ]
# 2024-05-05 05:41:57,879 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:42:26,173 [INFO] >>>> TOTAL TIME 64.93 sec
# 2024-05-05 05:42:26,521 [INFO] 0%|          | 10/3080 [29:02<185:28:42, 217.50s/it]
# 2024-05-05 05:42:26,534 [INFO] channels set to [0, 0]
# 2024-05-05 05:42:26,534 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:43:00,653 [INFO] estimated cell diameter(s) in 34.12 sec
# 2024-05-05 05:43:00,654 [INFO] >>> diameter(s) =
# 2024-05-05 05:43:00,654 [INFO] [ 76.61 ]
# 2024-05-05 05:43:00,654 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:43:17,032 [INFO] >>>> TOTAL TIME 50.50 sec
# 2024-05-05 05:43:17,351 [INFO] 0%|          | 11/3080 [29:53<141:55:57, 166.49s/it]
# 2024-05-05 05:43:17,363 [INFO] channels set to [0, 0]
# 2024-05-05 05:43:17,363 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:44:34,223 [INFO] estimated cell diameter(s) in 76.86 sec
# 2024-05-05 05:44:34,223 [INFO] >>> diameter(s) =
# 2024-05-05 05:44:34,223 [INFO] [ 12.13 ]
# 2024-05-05 05:44:34,223 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:46:08,655 [INFO] >>>> TOTAL TIME 171.29 sec
# 2024-05-05 05:46:08,994 [INFO] 0%|          | 12/3080 [32:45<143:13:20, 168.06s/it]
# 2024-05-05 05:46:09,018 [INFO] channels set to [0, 0]
# 2024-05-05 05:46:09,018 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:47:24,908 [INFO] estimated cell diameter(s) in 75.89 sec
# 2024-05-05 05:47:24,908 [INFO] >>> diameter(s) =
# 2024-05-05 05:47:24,908 [INFO] [ 14.71 ]
# 2024-05-05 05:47:24,908 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:48:35,210 [INFO] >>>> TOTAL TIME 146.19 sec
# 2024-05-05 05:48:35,527 [INFO] 0%|          | 13/3080 [35:11<137:37:13, 161.54s/it]
# 2024-05-05 05:48:35,541 [INFO] channels set to [0, 0]
# 2024-05-05 05:48:35,541 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:49:38,047 [INFO] estimated cell diameter(s) in 62.51 sec
# 2024-05-05 05:49:38,047 [INFO] >>> diameter(s) =
# 2024-05-05 05:49:38,048 [INFO] [ 13.21 ]
# 2024-05-05 05:49:38,048 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:51:04,225 [INFO] >>>> TOTAL TIME 148.68 sec
# 2024-05-05 05:51:04,535 [INFO] 0%|          | 14/3080 [37:40<134:21:09, 157.75s/it]
# 2024-05-05 05:51:04,855 [INFO] channels set to [0, 0]
# 2024-05-05 05:51:04,856 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:51:38,725 [INFO] estimated cell diameter(s) in 33.87 sec
# 2024-05-05 05:51:38,725 [INFO] >>> diameter(s) =
# 2024-05-05 05:51:38,725 [INFO] [ 31.47 ]
# 2024-05-05 05:51:38,725 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:51:59,824 [INFO] >>>> TOTAL TIME 54.97 sec
# 2024-05-05 05:52:00,214 [INFO] 0%|          | 15/3080 [38:36<108:06:47, 126.98s/it]
# 2024-05-05 05:52:00,228 [INFO] channels set to [0, 0]
# 2024-05-05 05:52:00,228 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:52:38,926 [INFO] estimated cell diameter(s) in 38.70 sec
# 2024-05-05 05:52:38,927 [INFO] >>> diameter(s) =
# 2024-05-05 05:52:38,927 [INFO] [ 69.80 ]
# 2024-05-05 05:52:38,927 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:52:54,343 [INFO] >>>> TOTAL TIME 54.12 sec
# 2024-05-05 05:52:54,719 [INFO] 1%|          | 16/3080 [39:30<89:30:34, 105.17s/it]
# 2024-05-05 05:52:54,732 [INFO] channels set to [0, 0]
# 2024-05-05 05:52:54,732 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:53:58,261 [INFO] estimated cell diameter(s) in 63.53 sec
# 2024-05-05 05:53:58,261 [INFO] >>> diameter(s) =
# 2024-05-05 05:53:58,261 [INFO] [ 13.42 ]
# 2024-05-05 05:53:58,261 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:55:25,695 [INFO] >>>> TOTAL TIME 150.96 sec
# 2024-05-05 05:55:26,020 [INFO] 1%|          | 17/3080 [42:02<101:17:00, 119.04s/it]
# 2024-05-05 05:55:26,035 [INFO] channels set to [0, 0]
# 2024-05-05 05:55:26,035 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:56:31,437 [INFO] estimated cell diameter(s) in 65.40 sec
# 2024-05-05 05:56:31,438 [INFO] >>> diameter(s) =
# 2024-05-05 05:56:31,438 [INFO] [ 15.59 ]
# 2024-05-05 05:56:31,438 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 05:57:32,303 [INFO] >>>> TOTAL TIME 126.27 sec
# 2024-05-05 05:57:32,721 [INFO] 1%|          | 18/3080 [44:08<103:12:30, 121.34s/it]
# 2024-05-05 05:57:32,734 [INFO] channels set to [0, 0]
# 2024-05-05 05:57:32,735 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 05:58:33,312 [INFO] estimated cell diameter(s) in 60.58 sec
# 2024-05-05 05:58:33,312 [INFO] >>> diameter(s) =
# 2024-05-05 05:58:33,312 [INFO] [ 12.26 ]
# 2024-05-05 05:58:33,313 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:00:00,049 [INFO] >>>> TOTAL TIME 147.31 sec
# 2024-05-05 06:00:00,410 [INFO] 1%|          | 19/3080 [46:36<109:54:10, 129.26s/it]
# 2024-05-05 06:00:00,423 [INFO] channels set to [0, 0]
# 2024-05-05 06:00:00,423 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:00:30,410 [INFO] estimated cell diameter(s) in 29.99 sec
# 2024-05-05 06:00:30,410 [INFO] >>> diameter(s) =
# 2024-05-05 06:00:30,411 [INFO] [ 34.64 ]
# 2024-05-05 06:00:30,411 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:00:46,642 [INFO] >>>> TOTAL TIME 46.22 sec
# 2024-05-05 06:00:46,945 [INFO] 1%|          | 20/3080 [47:23<88:45:23, 104.42s/it]
# 2024-05-05 06:00:46,957 [INFO] channels set to [0, 0]
# 2024-05-05 06:00:46,957 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:01:16,637 [INFO] estimated cell diameter(s) in 29.68 sec
# 2024-05-05 06:01:16,638 [INFO] >>> diameter(s) =
# 2024-05-05 06:01:16,638 [INFO] [ 60.42 ]
# 2024-05-05 06:01:16,638 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:01:40,896 [INFO] >>>> TOTAL TIME 53.94 sec
# 2024-05-05 06:01:41,230 [INFO] 1%|          | 21/3080 [48:17<75:56:24, 89.37s/it]
# 2024-05-05 06:01:41,242 [INFO] channels set to [0, 0]
# 2024-05-05 06:01:41,242 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:02:29,297 [INFO] estimated cell diameter(s) in 48.05 sec
# 2024-05-05 06:02:29,297 [INFO] >>> diameter(s) =
# 2024-05-05 06:02:29,297 [INFO] [ 32.90 ]
# 2024-05-05 06:02:29,297 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:02:55,146 [INFO] >>>> TOTAL TIME 73.90 sec
# 2024-05-05 06:02:55,449 [INFO] 1%|          | 22/3080 [49:31<72:03:09, 84.82s/it]
# 2024-05-05 06:02:55,468 [INFO] channels set to [0, 0]
# 2024-05-05 06:02:55,468 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:04:14,455 [INFO] estimated cell diameter(s) in 78.99 sec
# 2024-05-05 06:04:14,455 [INFO] >>> diameter(s) =
# 2024-05-05 06:04:14,455 [INFO] [ 16.98 ]
# 2024-05-05 06:04:14,455 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:05:09,572 [INFO] >>>> TOTAL TIME 134.10 sec
# 2024-05-05 06:05:09,920 [INFO] 1%|          | 23/3080 [51:45<84:40:49, 99.72s/it]
# 2024-05-05 06:05:09,937 [INFO] channels set to [0, 0]
# 2024-05-05 06:05:09,937 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:06:12,243 [INFO] estimated cell diameter(s) in 62.31 sec
# 2024-05-05 06:06:12,243 [INFO] >>> diameter(s) =
# 2024-05-05 06:06:12,243 [INFO] [ 14.23 ]
# 2024-05-05 06:06:12,243 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:07:31,207 [INFO] >>>> TOTAL TIME 141.27 sec
# 2024-05-05 06:07:31,547 [INFO] 1%|          | 24/3080 [54:07<95:19:35, 112.30s/it]
# 2024-05-05 06:07:31,564 [INFO] channels set to [0, 0]
# 2024-05-05 06:07:31,564 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:08:05,913 [INFO] estimated cell diameter(s) in 34.35 sec
# 2024-05-05 06:08:05,913 [INFO] >>> diameter(s) =
# 2024-05-05 06:08:05,913 [INFO] [ 31.78 ]
# 2024-05-05 06:08:05,914 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:08:27,107 [INFO] >>>> TOTAL TIME 55.54 sec
# 2024-05-05 06:08:27,541 [INFO] 1%|          | 25/3080 [55:03<80:57:35, 95.40s/it]
# 2024-05-05 06:08:27,564 [INFO] channels set to [0, 0]
# 2024-05-05 06:08:27,564 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:08:55,718 [INFO] estimated cell diameter(s) in 28.15 sec
# 2024-05-05 06:08:55,719 [INFO] >>> diameter(s) =
# 2024-05-05 06:08:55,719 [INFO] [ 58.46 ]
# 2024-05-05 06:08:55,719 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:09:20,848 [INFO] >>>> TOTAL TIME 53.28 sec
# 2024-05-05 06:09:21,191 [INFO] 1%|          | 26/3080 [55:57<70:18:22, 82.88s/it]
# 2024-05-05 06:09:21,208 [INFO] channels set to [0, 0]
# 2024-05-05 06:09:21,208 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:11:05,736 [INFO] estimated cell diameter(s) in 104.53 sec
# 2024-05-05 06:11:05,737 [INFO] >>> diameter(s) =
# 2024-05-05 06:11:05,737 [INFO] [ 34.83 ]
# 2024-05-05 06:11:05,737 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:11:42,563 [INFO] >>>> TOTAL TIME 141.36 sec
# 2024-05-05 06:11:43,237 [INFO] 1%|          | 27/3080 [58:19<85:20:17, 100.63s/it]
# 2024-05-05 06:11:43,259 [INFO] channels set to [0, 0]
# 2024-05-05 06:11:43,259 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:14:31,807 [INFO] estimated cell diameter(s) in 168.55 sec
# 2024-05-05 06:14:31,808 [INFO] >>> diameter(s) =
# 2024-05-05 06:14:31,808 [INFO] [ 13.59 ]
# 2024-05-05 06:14:31,808 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:15:57,460 [INFO] >>>> TOTAL TIME 254.20 sec
# 2024-05-05 06:15:57,965 [INFO] 1%|          | 28/3080 [1:02:34<124:30:17, 146.86s/it]
# 2024-05-05 06:15:57,989 [INFO] channels set to [0, 0]
# 2024-05-05 06:15:57,989 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:17:02,745 [INFO] estimated cell diameter(s) in 64.76 sec
# 2024-05-05 06:17:02,745 [INFO] >>> diameter(s) =
# 2024-05-05 06:17:02,745 [INFO] [ 12.15 ]
# 2024-05-05 06:17:02,745 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:18:39,824 [INFO] >>>> TOTAL TIME 161.84 sec
# 2024-05-05 06:18:40,173 [INFO] 1%|          | 29/3080 [1:05:16<128:21:58, 151.46s/it]
# 2024-05-05 06:18:40,194 [INFO] channels set to [0, 0]
# 2024-05-05 06:18:40,195 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:19:18,931 [INFO] estimated cell diameter(s) in 38.74 sec
# 2024-05-05 06:19:18,931 [INFO] >>> diameter(s) =
# 2024-05-05 06:19:18,931 [INFO] [ 30.57 ]
# 2024-05-05 06:19:18,931 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:19:42,462 [INFO] >>>> TOTAL TIME 62.27 sec
# 2024-05-05 06:19:42,844 [INFO] 1%|          | 30/3080 [1:06:18<105:45:19, 124.83s/it]
# 2024-05-05 06:19:42,861 [INFO] channels set to [0, 0]
# 2024-05-05 06:19:42,861 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:20:12,896 [INFO] estimated cell diameter(s) in 30.04 sec
# 2024-05-05 06:20:12,897 [INFO] >>> diameter(s) =
# 2024-05-05 06:20:12,897 [INFO] [ 57.93 ]
# 2024-05-05 06:20:12,897 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:20:39,771 [INFO] >>>> TOTAL TIME 56.91 sec
# 2024-05-05 06:20:40,117 [INFO] 1%|1         | 31/3080 [1:07:16<88:33:23, 104.56s/it]
# 2024-05-05 06:20:40,132 [INFO] channels set to [0, 0]
# 2024-05-05 06:20:40,133 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:21:43,090 [INFO] estimated cell diameter(s) in 62.96 sec
# 2024-05-05 06:21:43,090 [INFO] >>> diameter(s) =
# 2024-05-05 06:21:43,090 [INFO] [ 31.19 ]
# 2024-05-05 06:21:43,091 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:22:14,141 [INFO] >>>> TOTAL TIME 94.01 sec
# 2024-05-05 06:22:14,635 [INFO] 1%|1         | 32/3080 [1:08:50<85:58:35, 101.55s/it]
# 2024-05-05 06:22:14,651 [INFO] channels set to [0, 0]
# 2024-05-05 06:22:14,651 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:24:33,556 [INFO] estimated cell diameter(s) in 138.90 sec
# 2024-05-05 06:24:33,557 [INFO] >>> diameter(s) =
# 2024-05-05 06:24:33,557 [INFO] [ 15.86 ]
# 2024-05-05 06:24:33,557 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:25:50,535 [INFO] >>>> TOTAL TIME 215.88 sec
# 2024-05-05 06:25:51,032 [INFO] 1%|1         | 33/3080 [1:12:27<115:06:38, 136.00s/it]
# 2024-05-05 06:25:51,055 [INFO] channels set to [0, 0]
# 2024-05-05 06:25:51,055 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:27:00,263 [INFO] estimated cell diameter(s) in 69.21 sec
# 2024-05-05 06:27:00,263 [INFO] >>> diameter(s) =
# 2024-05-05 06:27:00,263 [INFO] [ 16.41 ]
# 2024-05-05 06:27:00,263 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:27:59,228 [INFO] >>>> TOTAL TIME 128.17 sec
# 2024-05-05 06:27:59,710 [INFO] 1%|1         | 34/3080 [1:14:35<113:12:50, 133.81s/it]
# 2024-05-05 06:27:59,727 [INFO] channels set to [0, 0]
# 2024-05-05 06:27:59,727 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:28:34,849 [INFO] estimated cell diameter(s) in 35.12 sec
# 2024-05-05 06:28:34,849 [INFO] >>> diameter(s) =
# 2024-05-05 06:28:34,849 [INFO] [ 34.34 ]
# 2024-05-05 06:28:34,849 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:28:57,434 [INFO] >>>> TOTAL TIME 57.71 sec
# 2024-05-05 06:28:57,810 [INFO] 1%|1         | 35/3080 [1:15:33<93:58:00, 111.09s/it]
# 2024-05-05 06:28:57,831 [INFO] channels set to [0, 0]
# 2024-05-05 06:28:57,832 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:29:30,712 [INFO] estimated cell diameter(s) in 32.88 sec
# 2024-05-05 06:29:30,712 [INFO] >>> diameter(s) =
# 2024-05-05 06:29:30,712 [INFO] [ 59.31 ]
# 2024-05-05 06:29:30,712 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:29:55,649 [INFO] >>>> TOTAL TIME 57.82 sec
# 2024-05-05 06:29:56,040 [INFO] 1%|1         | 36/3080 [1:16:32<80:31:33, 95.23s/it]
# 2024-05-05 06:29:56,058 [INFO] channels set to [0, 0]
# 2024-05-05 06:29:56,058 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:31:06,605 [INFO] estimated cell diameter(s) in 70.55 sec
# 2024-05-05 06:31:06,606 [INFO] >>> diameter(s) =
# 2024-05-05 06:31:06,606 [INFO] [ 15.01 ]
# 2024-05-05 06:31:06,606 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:32:19,477 [INFO] >>>> TOTAL TIME 143.42 sec
# 2024-05-05 06:32:20,477 [INFO] 1%|1         | 37/3080 [1:18:56<92:58:35, 110.00s/it]
# 2024-05-05 06:32:20,615 [INFO] channels set to [0, 0]
# 2024-05-05 06:32:20,615 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:33:55,668 [INFO] estimated cell diameter(s) in 95.05 sec
# 2024-05-05 06:33:55,669 [INFO] >>> diameter(s) =
# 2024-05-05 06:33:55,669 [INFO] [ 14.49 ]
# 2024-05-05 06:33:55,669 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:34:57,704 [INFO] >>>> TOTAL TIME 157.09 sec
# 2024-05-05 06:34:58,020 [INFO] 1%|1         | 38/3080 [1:21:34<104:59:57, 124.26s/it]
# 2024-05-05 06:34:58,034 [INFO] channels set to [0, 0]
# 2024-05-05 06:34:58,034 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:36:01,373 [INFO] estimated cell diameter(s) in 63.34 sec
# 2024-05-05 06:36:01,373 [INFO] >>> diameter(s) =
# 2024-05-05 06:36:01,373 [INFO] [ 13.89 ]
# 2024-05-05 06:36:01,373 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:37:17,117 [INFO] >>>> TOTAL TIME 139.08 sec
# 2024-05-05 06:37:17,447 [INFO] 1%|1         | 39/3080 [1:23:53<108:48:31, 128.81s/it]
# 2024-05-05 06:37:17,575 [INFO] channels set to [0, 0]
# 2024-05-05 06:37:17,575 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:37:53,808 [INFO] estimated cell diameter(s) in 36.23 sec
# 2024-05-05 06:37:53,809 [INFO] >>> diameter(s) =
# 2024-05-05 06:37:53,809 [INFO] [ 32.01 ]
# 2024-05-05 06:37:53,809 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:38:15,739 [INFO] >>>> TOTAL TIME 58.16 sec
# 2024-05-05 06:38:17,402 [INFO] 1%|1         | 40/3080 [1:24:53<91:19:45, 108.15s/it]
# 2024-05-05 06:38:17,497 [INFO] channels set to [0, 0]
# 2024-05-05 06:38:17,497 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:38:47,269 [INFO] estimated cell diameter(s) in 29.77 sec
# 2024-05-05 06:38:47,270 [INFO] >>> diameter(s) =
# 2024-05-05 06:38:47,270 [INFO] [ 57.77 ]
# 2024-05-05 06:38:47,270 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:39:11,327 [INFO] >>>> TOTAL TIME 53.83 sec
# 2024-05-05 06:39:13,524 [INFO] 1%|1         | 41/3080 [1:25:49<78:07:21, 92.54s/it]
# 2024-05-05 06:39:13,631 [INFO] channels set to [0, 0]
# 2024-05-05 06:39:13,631 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:40:07,333 [INFO] estimated cell diameter(s) in 53.70 sec
# 2024-05-05 06:40:07,333 [INFO] >>> diameter(s) =
# 2024-05-05 06:40:07,333 [INFO] [ 18.95 ]
# 2024-05-05 06:40:07,333 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:40:58,913 [INFO] >>>> TOTAL TIME 105.28 sec
# 2024-05-05 06:40:59,826 [INFO] 1%|1         | 42/3080 [1:27:35<81:34:47, 96.67s/it]
# 2024-05-05 06:40:59,840 [INFO] channels set to [0, 0]
# 2024-05-05 06:40:59,840 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:42:19,838 [INFO] estimated cell diameter(s) in 80.00 sec
# 2024-05-05 06:42:19,839 [INFO] >>> diameter(s) =
# 2024-05-05 06:42:19,839 [INFO] [ 16.45 ]
# 2024-05-05 06:42:19,839 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:43:11,471 [INFO] >>>> TOTAL TIME 131.63 sec
# 2024-05-05 06:43:11,764 [INFO] 1%|1         | 43/3080 [1:29:47<90:28:42, 107.25s/it]
# 2024-05-05 06:43:11,781 [INFO] channels set to [0, 0]
# 2024-05-05 06:43:11,781 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:44:08,260 [INFO] estimated cell diameter(s) in 56.48 sec
# 2024-05-05 06:44:08,260 [INFO] >>> diameter(s) =
# 2024-05-05 06:44:08,261 [INFO] [ 15.20 ]
# 2024-05-05 06:44:08,261 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:45:11,149 [INFO] >>>> TOTAL TIME 119.37 sec
# 2024-05-05 06:45:11,465 [INFO] 1%|1         | 44/3080 [1:31:47<93:35:54, 110.99s/it]
# 2024-05-05 06:45:11,479 [INFO] channels set to [0, 0]
# 2024-05-05 06:45:11,480 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:45:48,844 [INFO] estimated cell diameter(s) in 37.36 sec
# 2024-05-05 06:45:48,844 [INFO] >>> diameter(s) =
# 2024-05-05 06:45:48,844 [INFO] [ 36.65 ]
# 2024-05-05 06:45:48,844 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:46:09,461 [INFO] >>>> TOTAL TIME 57.98 sec
# 2024-05-05 06:46:09,756 [INFO] 1%|1         | 45/3080 [1:32:45<80:14:24, 95.18s/it]
# 2024-05-05 06:46:09,782 [INFO] channels set to [0, 0]
# 2024-05-05 06:46:09,782 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:46:41,799 [INFO] estimated cell diameter(s) in 32.02 sec
# 2024-05-05 06:46:41,799 [INFO] >>> diameter(s) =
# 2024-05-05 06:46:41,799 [INFO] [ 56.99 ]
# 2024-05-05 06:46:41,799 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:47:04,624 [INFO] >>>> TOTAL TIME 54.84 sec
# 2024-05-05 06:47:05,073 [INFO] 1%|1         | 46/3080 [1:33:41<70:08:08, 83.22s/it]
# 2024-05-05 06:47:05,086 [INFO] channels set to [0, 0]
# 2024-05-05 06:47:05,087 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:48:02,599 [INFO] estimated cell diameter(s) in 57.51 sec
# 2024-05-05 06:48:02,599 [INFO] >>> diameter(s) =
# 2024-05-05 06:48:02,599 [INFO] [ 22.01 ]
# 2024-05-05 06:48:02,599 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:48:39,661 [INFO] >>>> TOTAL TIME 94.57 sec
# 2024-05-05 06:48:40,216 [INFO] 2%|1         | 47/3080 [1:35:16<73:07:33, 86.80s/it]
# 2024-05-05 06:48:40,292 [INFO] channels set to [0, 0]
# 2024-05-05 06:48:40,292 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:49:59,348 [INFO] estimated cell diameter(s) in 79.06 sec
# 2024-05-05 06:49:59,349 [INFO] >>> diameter(s) =
# 2024-05-05 06:49:59,349 [INFO] [ 17.63 ]
# 2024-05-05 06:49:59,349 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:50:54,193 [INFO] >>>> TOTAL TIME 133.90 sec
# 2024-05-05 06:50:54,490 [INFO] 2%|1         | 48/3080 [1:37:30<85:05:52, 101.04s/it]
# 2024-05-05 06:50:54,504 [INFO] channels set to [0, 0]
# 2024-05-05 06:50:54,504 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:51:53,553 [INFO] estimated cell diameter(s) in 59.05 sec
# 2024-05-05 06:51:53,553 [INFO] >>> diameter(s) =
# 2024-05-05 06:51:53,553 [INFO] [ 12.18 ]
# 2024-05-05 06:51:53,553 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:53:12,213 [INFO] >>>> TOTAL TIME 137.71 sec
# 2024-05-05 06:53:12,538 [INFO] 2%|1         | 49/3080 [1:39:48<94:25:03, 112.14s/it]
# 2024-05-05 06:53:12,553 [INFO] channels set to [0, 0]
# 2024-05-05 06:53:12,554 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:53:49,510 [INFO] estimated cell diameter(s) in 36.96 sec
# 2024-05-05 06:53:49,510 [INFO] >>> diameter(s) =
# 2024-05-05 06:53:49,510 [INFO] [ 32.56 ]
# 2024-05-05 06:53:49,510 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:54:11,176 [INFO] >>>> TOTAL TIME 58.62 sec
# 2024-05-05 06:54:11,475 [INFO] 2%|1         | 50/3080 [1:40:47<80:57:07, 96.18s/it]
# 2024-05-05 06:54:11,499 [INFO] channels set to [0, 0]
# 2024-05-05 06:54:11,500 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:54:43,742 [INFO] estimated cell diameter(s) in 32.24 sec
# 2024-05-05 06:54:43,742 [INFO] >>> diameter(s) =
# 2024-05-05 06:54:43,742 [INFO] [ 59.70 ]
# 2024-05-05 06:54:43,742 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:55:08,933 [INFO] >>>> TOTAL TIME 57.43 sec
# 2024-05-05 06:55:09,235 [INFO] 2%|1         | 51/3080 [1:41:45<71:13:38, 84.65s/it]
# 2024-05-05 06:55:09,260 [INFO] channels set to [0, 0]
# 2024-05-05 06:55:09,260 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:56:06,035 [INFO] estimated cell diameter(s) in 56.77 sec
# 2024-05-05 06:56:06,036 [INFO] >>> diameter(s) =
# 2024-05-05 06:56:06,036 [INFO] [ 11.64 ]
# 2024-05-05 06:56:06,036 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 06:57:37,357 [INFO] >>>> TOTAL TIME 148.10 sec
# 2024-05-05 06:57:37,694 [INFO] 2%|1         | 52/3080 [1:44:13<87:18:13, 103.80s/it]
# 2024-05-05 06:57:37,707 [INFO] channels set to [0, 0]
# 2024-05-05 06:57:37,707 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 06:59:15,310 [INFO] estimated cell diameter(s) in 97.60 sec
# 2024-05-05 06:59:15,310 [INFO] >>> diameter(s) =
# 2024-05-05 06:59:15,310 [INFO] [ 14.80 ]
# 2024-05-05 06:59:15,310 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:00:21,008 [INFO] >>>> TOTAL TIME 163.30 sec
# 2024-05-05 07:00:21,328 [INFO] 2%|1         | 53/3080 [1:46:57<102:22:08, 121.75s/it]
# 2024-05-05 07:00:21,351 [INFO] channels set to [0, 0]
# 2024-05-05 07:00:21,351 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:01:15,974 [INFO] estimated cell diameter(s) in 54.62 sec
# 2024-05-05 07:01:15,974 [INFO] >>> diameter(s) =
# 2024-05-05 07:01:15,974 [INFO] [ 14.76 ]
# 2024-05-05 07:01:15,974 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:02:14,295 [INFO] >>>> TOTAL TIME 112.94 sec
# 2024-05-05 07:02:14,613 [INFO] 2%|1         | 54/3080 [1:48:50<100:12:05, 119.21s/it]
# 2024-05-05 07:02:14,627 [INFO] channels set to [0, 0]
# 2024-05-05 07:02:14,627 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:02:50,522 [INFO] estimated cell diameter(s) in 35.89 sec
# 2024-05-05 07:02:50,522 [INFO] >>> diameter(s) =
# 2024-05-05 07:02:50,522 [INFO] [ 29.59 ]
# 2024-05-05 07:02:50,522 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:03:10,956 [INFO] >>>> TOTAL TIME 56.33 sec
# 2024-05-05 07:03:11,313 [INFO] 2%|1         | 55/3080 [1:49:47<84:24:39, 100.46s/it]
# 2024-05-05 07:03:11,326 [INFO] channels set to [0, 0]
# 2024-05-05 07:03:11,327 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:03:45,180 [INFO] estimated cell diameter(s) in 33.85 sec
# 2024-05-05 07:03:45,181 [INFO] >>> diameter(s) =
# 2024-05-05 07:03:45,181 [INFO] [ 58.27 ]
# 2024-05-05 07:03:45,181 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:04:07,001 [INFO] >>>> TOTAL TIME 55.68 sec
# 2024-05-05 07:04:07,501 [INFO] 2%|1         | 56/3080 [1:50:43<73:13:38, 87.18s/it]
# 2024-05-05 07:04:07,514 [INFO] channels set to [0, 0]
# 2024-05-05 07:04:07,515 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:05:00,131 [INFO] estimated cell diameter(s) in 52.62 sec
# 2024-05-05 07:05:00,132 [INFO] >>> diameter(s) =
# 2024-05-05 07:05:00,132 [INFO] [ 18.05 ]
# 2024-05-05 07:05:00,132 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:05:43,134 [INFO] >>>> TOTAL TIME 95.62 sec
# 2024-05-05 07:05:43,437 [INFO] 2%|1         | 57/3080 [1:52:19<75:24:36, 89.80s/it]
# 2024-05-05 07:05:43,461 [INFO] channels set to [0, 0]
# 2024-05-05 07:05:43,461 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:07:01,099 [INFO] estimated cell diameter(s) in 77.64 sec
# 2024-05-05 07:07:01,099 [INFO] >>> diameter(s) =
# 2024-05-05 07:07:01,099 [INFO] [ 17.20 ]
# 2024-05-05 07:07:01,099 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:07:56,507 [INFO] >>>> TOTAL TIME 133.05 sec
# 2024-05-05 07:07:56,800 [INFO] 2%|1         | 58/3080 [1:54:32<86:21:17, 102.87s/it]
# 2024-05-05 07:07:56,816 [INFO] channels set to [0, 0]
# 2024-05-05 07:07:56,816 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:08:55,387 [INFO] estimated cell diameter(s) in 58.57 sec
# 2024-05-05 07:08:55,387 [INFO] >>> diameter(s) =
# 2024-05-05 07:08:55,387 [INFO] [ 14.71 ]
# 2024-05-05 07:08:55,387 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:09:53,860 [INFO] >>>> TOTAL TIME 117.04 sec
# 2024-05-05 07:09:54,159 [INFO] 2%|1         | 59/3080 [1:56:30<89:58:25, 107.22s/it]
# 2024-05-05 07:09:54,172 [INFO] channels set to [0, 0]
# 2024-05-05 07:09:54,173 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:10:34,636 [INFO] estimated cell diameter(s) in 40.46 sec
# 2024-05-05 07:10:34,636 [INFO] >>> diameter(s) =
# 2024-05-05 07:10:34,636 [INFO] [ 29.81 ]
# 2024-05-05 07:10:34,636 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:10:55,321 [INFO] >>>> TOTAL TIME 61.15 sec
# 2024-05-05 07:10:55,662 [INFO] 2%|1         | 60/3080 [1:57:31<78:26:20, 93.50s/it]
# 2024-05-05 07:10:55,720 [INFO] channels set to [0, 0]
# 2024-05-05 07:10:55,720 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:11:25,613 [INFO] estimated cell diameter(s) in 29.89 sec
# 2024-05-05 07:11:25,613 [INFO] >>> diameter(s) =
# 2024-05-05 07:11:25,614 [INFO] [ 56.11 ]
# 2024-05-05 07:11:25,614 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:11:46,737 [INFO] >>>> TOTAL TIME 51.02 sec
# 2024-05-05 07:11:47,064 [INFO] 2%|1         | 61/3080 [1:58:23<67:49:15, 80.87s/it]
# 2024-05-05 07:11:47,077 [INFO] channels set to [0, 0]
# 2024-05-05 07:11:47,078 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:12:40,968 [INFO] estimated cell diameter(s) in 53.89 sec
# 2024-05-05 07:12:40,968 [INFO] >>> diameter(s) =
# 2024-05-05 07:12:40,968 [INFO] [ 23.06 ]
# 2024-05-05 07:12:40,968 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:13:17,435 [INFO] >>>> TOTAL TIME 90.36 sec
# 2024-05-05 07:13:17,831 [INFO] 2%|2         | 62/3080 [1:59:53<70:17:12, 83.84s/it]
# 2024-05-05 07:13:17,854 [INFO] channels set to [0, 0]
# 2024-05-05 07:13:17,854 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:14:32,484 [INFO] estimated cell diameter(s) in 74.63 sec
# 2024-05-05 07:14:32,484 [INFO] >>> diameter(s) =
# 2024-05-05 07:14:32,484 [INFO] [ 16.23 ]
# 2024-05-05 07:14:32,484 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:15:34,432 [INFO] >>>> TOTAL TIME 136.58 sec
# 2024-05-05 07:15:35,152 [INFO] 2%|2         | 63/3080 [2:02:11<83:42:33, 99.89s/it]
# 2024-05-05 07:15:35,168 [INFO] channels set to [0, 0]
# 2024-05-05 07:15:35,168 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:16:44,096 [INFO] estimated cell diameter(s) in 68.93 sec
# 2024-05-05 07:16:44,096 [INFO] >>> diameter(s) =
# 2024-05-05 07:16:44,096 [INFO] [ 13.49 ]
# 2024-05-05 07:16:44,096 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:18:00,454 [INFO] >>>> TOTAL TIME 145.29 sec
# 2024-05-05 07:18:00,759 [INFO] 2%|2         | 64/3080 [2:04:36<95:10:22, 113.60s/it]
# 2024-05-05 07:18:00,774 [INFO] channels set to [0, 0]
# 2024-05-05 07:18:00,774 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:18:40,695 [INFO] estimated cell diameter(s) in 39.92 sec
# 2024-05-05 07:18:40,696 [INFO] >>> diameter(s) =
# 2024-05-05 07:18:40,696 [INFO] [ 29.60 ]
# 2024-05-05 07:18:40,696 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:19:01,676 [INFO] >>>> TOTAL TIME 60.90 sec
# 2024-05-05 07:19:01,986 [INFO] 2%|2         | 65/3080 [2:05:38<81:58:56, 97.89s/it]
# 2024-05-05 07:19:02,009 [INFO] channels set to [0, 0]
# 2024-05-05 07:19:02,009 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:19:34,478 [INFO] estimated cell diameter(s) in 32.47 sec
# 2024-05-05 07:19:34,478 [INFO] >>> diameter(s) =
# 2024-05-05 07:19:34,478 [INFO] [ 56.93 ]
# 2024-05-05 07:19:34,478 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:19:56,529 [INFO] >>>> TOTAL TIME 54.52 sec
# 2024-05-05 07:19:56,927 [INFO] 2%|2         | 66/3080 [2:06:32<71:10:04, 85.00s/it]
# 2024-05-05 07:19:56,948 [INFO] channels set to [0, 0]
# 2024-05-05 07:19:56,948 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:20:39,127 [INFO] estimated cell diameter(s) in 42.18 sec
# 2024-05-05 07:20:39,127 [INFO] >>> diameter(s) =
# 2024-05-05 07:20:39,127 [INFO] [ 44.47 ]
# 2024-05-05 07:20:39,127 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:21:00,802 [INFO] >>>> TOTAL TIME 63.85 sec
# 2024-05-05 07:21:01,102 [INFO] 2%|2         | 67/3080 [2:07:37<65:54:51, 78.76s/it]
# 2024-05-05 07:21:01,129 [INFO] channels set to [0, 0]
# 2024-05-05 07:21:01,129 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:22:16,846 [INFO] estimated cell diameter(s) in 75.72 sec
# 2024-05-05 07:22:16,846 [INFO] >>> diameter(s) =
# 2024-05-05 07:22:16,846 [INFO] [ 14.45 ]
# 2024-05-05 07:22:16,846 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:23:20,950 [INFO] >>>> TOTAL TIME 139.82 sec
# 2024-05-05 07:23:21,271 [INFO] 2%|2         | 68/3080 [2:09:57<81:18:25, 97.18s/it]
# 2024-05-05 07:23:21,284 [INFO] channels set to [0, 0]
# 2024-05-05 07:23:21,284 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:24:21,649 [INFO] estimated cell diameter(s) in 60.36 sec
# 2024-05-05 07:24:21,649 [INFO] >>> diameter(s) =
# 2024-05-05 07:24:21,649 [INFO] [ 13.01 ]
# 2024-05-05 07:24:21,649 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:25:36,526 [INFO] >>>> TOTAL TIME 135.24 sec
# 2024-05-05 07:25:36,831 [INFO] 2%|2         | 69/3080 [2:12:12<90:54:37, 108.69s/it]
# 2024-05-05 07:25:36,844 [INFO] channels set to [0, 0]
# 2024-05-05 07:25:36,844 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:26:19,066 [INFO] estimated cell diameter(s) in 42.22 sec
# 2024-05-05 07:26:19,067 [INFO] >>> diameter(s) =
# 2024-05-05 07:26:19,067 [INFO] [ 25.47 ]
# 2024-05-05 07:26:19,067 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:26:48,320 [INFO] >>>> TOTAL TIME 71.48 sec
# 2024-05-05 07:26:48,614 [INFO] 2%|2         | 70/3080 [2:13:24<81:37:18, 97.62s/it]
# 2024-05-05 07:26:48,631 [INFO] channels set to [0, 0]
# 2024-05-05 07:26:48,631 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:27:19,096 [INFO] estimated cell diameter(s) in 30.47 sec
# 2024-05-05 07:27:19,097 [INFO] >>> diameter(s) =
# 2024-05-05 07:27:19,097 [INFO] [ 58.05 ]
# 2024-05-05 07:27:19,097 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:27:39,292 [INFO] >>>> TOTAL TIME 50.66 sec
# 2024-05-05 07:27:39,620 [INFO] 2%|2         | 71/3080 [2:14:15<69:54:21, 83.64s/it]
# 2024-05-05 07:27:39,635 [INFO] channels set to [0, 0]
# 2024-05-05 07:27:39,635 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:28:35,242 [INFO] estimated cell diameter(s) in 55.61 sec
# 2024-05-05 07:28:35,242 [INFO] >>> diameter(s) =
# 2024-05-05 07:28:35,243 [INFO] [ 12.13 ]
# 2024-05-05 07:28:35,243 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:29:58,183 [INFO] >>>> TOTAL TIME 138.55 sec
# 2024-05-05 07:29:58,540 [INFO] 2%|2         | 72/3080 [2:16:34<83:44:25, 100.22s/it]
# 2024-05-05 07:29:58,553 [INFO] channels set to [0, 0]
# 2024-05-05 07:29:58,553 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:31:17,457 [INFO] estimated cell diameter(s) in 78.90 sec
# 2024-05-05 07:31:17,457 [INFO] >>> diameter(s) =
# 2024-05-05 07:31:17,457 [INFO] [ 14.47 ]
# 2024-05-05 07:31:17,457 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:32:21,534 [INFO] >>>> TOTAL TIME 142.98 sec
# 2024-05-05 07:32:21,858 [INFO] 2%|2         | 73/3080 [2:18:57<94:30:42, 113.15s/it]
# 2024-05-05 07:32:21,871 [INFO] channels set to [0, 0]
# 2024-05-05 07:32:21,871 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:33:18,881 [INFO] estimated cell diameter(s) in 57.01 sec
# 2024-05-05 07:33:18,882 [INFO] >>> diameter(s) =
# 2024-05-05 07:33:18,882 [INFO] [ 14.93 ]
# 2024-05-05 07:33:18,882 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:34:21,890 [INFO] >>>> TOTAL TIME 120.02 sec
# 2024-05-05 07:34:22,179 [INFO] 2%|2         | 74/3080 [2:20:58<96:16:36, 115.30s/it]
# 2024-05-05 07:34:22,192 [INFO] channels set to [0, 0]
# 2024-05-05 07:34:22,192 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:34:58,838 [INFO] estimated cell diameter(s) in 36.65 sec
# 2024-05-05 07:34:58,838 [INFO] >>> diameter(s) =
# 2024-05-05 07:34:58,838 [INFO] [ 33.07 ]
# 2024-05-05 07:34:58,838 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:35:20,789 [INFO] >>>> TOTAL TIME 58.60 sec
# 2024-05-05 07:35:21,094 [INFO] 2%|2         | 75/3080 [2:21:57<82:07:28, 98.39s/it]
# 2024-05-05 07:35:21,112 [INFO] channels set to [0, 0]
# 2024-05-05 07:35:21,112 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:35:55,889 [INFO] estimated cell diameter(s) in 34.78 sec
# 2024-05-05 07:35:55,889 [INFO] >>> diameter(s) =
# 2024-05-05 07:35:55,889 [INFO] [ 57.28 ]
# 2024-05-05 07:35:55,889 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:36:17,003 [INFO] >>>> TOTAL TIME 55.89 sec
# 2024-05-05 07:36:17,289 [INFO] 2%|2         | 76/3080 [2:22:53<71:32:07, 85.73s/it]
# 2024-05-05 07:36:17,302 [INFO] channels set to [0, 0]
# 2024-05-05 07:36:17,302 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:37:15,869 [INFO] estimated cell diameter(s) in 58.57 sec
# 2024-05-05 07:37:15,869 [INFO] >>> diameter(s) =
# 2024-05-05 07:37:15,869 [INFO] [ 14.54 ]
# 2024-05-05 07:37:15,870 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:38:25,322 [INFO] >>>> TOTAL TIME 128.02 sec
# 2024-05-05 07:38:25,643 [INFO] 2%|2         | 77/3080 [2:25:01<82:10:43, 98.52s/it]
# 2024-05-05 07:38:25,664 [INFO] channels set to [0, 0]
# 2024-05-05 07:38:25,665 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:40:01,340 [INFO] estimated cell diameter(s) in 95.67 sec
# 2024-05-05 07:40:01,340 [INFO] >>> diameter(s) =
# 2024-05-05 07:40:01,340 [INFO] [ 13.84 ]
# 2024-05-05 07:40:01,340 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:41:13,213 [INFO] >>>> TOTAL TIME 167.55 sec
# 2024-05-05 07:41:13,528 [INFO] 3%|2         | 78/3080 [2:27:49<99:30:18, 119.33s/it]
# 2024-05-05 07:41:13,547 [INFO] channels set to [0, 0]
# 2024-05-05 07:41:13,548 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:42:07,189 [INFO] estimated cell diameter(s) in 53.64 sec
# 2024-05-05 07:42:07,190 [INFO] >>> diameter(s) =
# 2024-05-05 07:42:07,190 [INFO] [ 15.69 ]
# 2024-05-05 07:42:07,190 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:43:01,620 [INFO] >>>> TOTAL TIME 108.07 sec
# 2024-05-05 07:43:01,925 [INFO] 3%|2         | 79/3080 [2:29:37<96:44:19, 116.05s/it]
# 2024-05-05 07:43:01,944 [INFO] channels set to [0, 0]
# 2024-05-05 07:43:01,944 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:43:41,435 [INFO] estimated cell diameter(s) in 39.49 sec
# 2024-05-05 07:43:41,435 [INFO] >>> diameter(s) =
# 2024-05-05 07:43:41,436 [INFO] [ 33.95 ]
# 2024-05-05 07:43:41,436 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:44:02,785 [INFO] >>>> TOTAL TIME 60.84 sec
# 2024-05-05 07:44:03,237 [INFO] 3%|2         | 80/3080 [2:30:39<83:01:21, 99.63s/it]
# 2024-05-05 07:44:03,251 [INFO] channels set to [0, 0]
# 2024-05-05 07:44:03,251 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:44:37,434 [INFO] estimated cell diameter(s) in 34.18 sec
# 2024-05-05 07:44:37,435 [INFO] >>> diameter(s) =
# 2024-05-05 07:44:37,435 [INFO] [ 56.67 ]
# 2024-05-05 07:44:37,435 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:45:00,133 [INFO] >>>> TOTAL TIME 56.88 sec
# 2024-05-05 07:45:00,442 [INFO] 3%|2         | 81/3080 [2:31:36<72:23:34, 86.90s/it]
# 2024-05-05 07:45:00,457 [INFO] channels set to [0, 0]
# 2024-05-05 07:45:00,457 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:45:55,194 [INFO] estimated cell diameter(s) in 54.74 sec
# 2024-05-05 07:45:55,194 [INFO] >>> diameter(s) =
# 2024-05-05 07:45:55,194 [INFO] [ 18.18 ]
# 2024-05-05 07:45:55,194 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:46:40,493 [INFO] >>>> TOTAL TIME 100.04 sec
# 2024-05-05 07:46:40,819 [INFO] 3%|2         | 82/3080 [2:33:16<75:44:08, 90.94s/it]
# 2024-05-05 07:46:40,833 [INFO] channels set to [0, 0]
# 2024-05-05 07:46:40,833 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:47:42,570 [INFO] estimated cell diameter(s) in 61.74 sec
# 2024-05-05 07:47:42,571 [INFO] >>> diameter(s) =
# 2024-05-05 07:47:42,571 [INFO] [ 17.68 ]
# 2024-05-05 07:47:42,571 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:48:32,381 [INFO] >>>> TOTAL TIME 111.55 sec
# 2024-05-05 07:48:32,709 [INFO] 3%|2         | 83/3080 [2:35:08<80:56:30, 97.23s/it]
# 2024-05-05 07:48:32,722 [INFO] channels set to [0, 0]
# 2024-05-05 07:48:32,722 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:49:28,636 [INFO] estimated cell diameter(s) in 55.91 sec
# 2024-05-05 07:49:28,636 [INFO] >>> diameter(s) =
# 2024-05-05 07:49:28,636 [INFO] [ 19.31 ]
# 2024-05-05 07:49:28,636 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:50:07,580 [INFO] >>>> TOTAL TIME 94.86 sec
# 2024-05-05 07:50:07,870 [INFO] 3%|2         | 84/3080 [2:36:43<80:23:55, 96.61s/it]
# 2024-05-05 07:50:07,908 [INFO] channels set to [0, 0]
# 2024-05-05 07:50:07,908 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:50:40,322 [INFO] estimated cell diameter(s) in 32.41 sec
# 2024-05-05 07:50:40,322 [INFO] >>> diameter(s) =
# 2024-05-05 07:50:40,322 [INFO] [ 36.93 ]
# 2024-05-05 07:50:40,322 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:51:00,616 [INFO] >>>> TOTAL TIME 52.71 sec
# 2024-05-05 07:51:01,154 [INFO] 3%|2         | 85/3080 [2:37:37<69:33:32, 83.61s/it]
# 2024-05-05 07:51:01,167 [INFO] channels set to [0, 0]
# 2024-05-05 07:51:01,167 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:51:30,683 [INFO] estimated cell diameter(s) in 29.52 sec
# 2024-05-05 07:51:30,683 [INFO] >>> diameter(s) =
# 2024-05-05 07:51:30,684 [INFO] [ 57.48 ]
# 2024-05-05 07:51:30,684 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:51:56,383 [INFO] >>>> TOTAL TIME 55.22 sec
# 2024-05-05 07:51:56,715 [INFO] 3%|2         | 86/3080 [2:38:32<62:32:15, 75.20s/it]
# 2024-05-05 07:51:56,728 [INFO] channels set to [0, 0]
# 2024-05-05 07:51:56,728 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:52:45,251 [INFO] estimated cell diameter(s) in 48.52 sec
# 2024-05-05 07:52:45,251 [INFO] >>> diameter(s) =
# 2024-05-05 07:52:45,251 [INFO] [ 17.95 ]
# 2024-05-05 07:52:45,251 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:53:27,615 [INFO] >>>> TOTAL TIME 90.89 sec
# 2024-05-05 07:53:27,925 [INFO] 3%|2         | 87/3080 [2:40:03<66:30:39, 80.00s/it]
# 2024-05-05 07:53:27,951 [INFO] channels set to [0, 0]
# 2024-05-05 07:53:27,952 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:54:57,581 [INFO] estimated cell diameter(s) in 89.63 sec
# 2024-05-05 07:54:57,581 [INFO] >>> diameter(s) =
# 2024-05-05 07:54:57,581 [INFO] [ 15.96 ]
# 2024-05-05 07:54:57,581 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:55:56,984 [INFO] >>>> TOTAL TIME 149.03 sec
# 2024-05-05 07:55:57,287 [INFO] 3%|2         | 88/3080 [2:42:33<83:46:59, 100.81s/it]
# 2024-05-05 07:55:57,308 [INFO] channels set to [0, 0]
# 2024-05-05 07:55:57,308 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:56:53,386 [INFO] estimated cell diameter(s) in 56.08 sec
# 2024-05-05 07:56:53,387 [INFO] >>> diameter(s) =
# 2024-05-05 07:56:53,387 [INFO] [ 12.57 ]
# 2024-05-05 07:56:53,387 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:58:21,633 [INFO] >>>> TOTAL TIME 144.33 sec
# 2024-05-05 07:58:21,968 [INFO] 3%|2         | 89/3080 [2:44:58<94:41:24, 113.97s/it]
# 2024-05-05 07:58:21,982 [INFO] channels set to [0, 0]
# 2024-05-05 07:58:21,982 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:58:59,846 [INFO] estimated cell diameter(s) in 37.86 sec
# 2024-05-05 07:58:59,846 [INFO] >>> diameter(s) =
# 2024-05-05 07:58:59,846 [INFO] [ 33.15 ]
# 2024-05-05 07:58:59,846 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 07:59:22,420 [INFO] >>>> TOTAL TIME 60.44 sec
# 2024-05-05 07:59:22,757 [INFO] 3%|2         | 90/3080 [2:45:58<81:24:27, 98.02s/it]
# 2024-05-05 07:59:22,773 [INFO] channels set to [0, 0]
# 2024-05-05 07:59:22,773 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 07:59:52,209 [INFO] estimated cell diameter(s) in 29.44 sec
# 2024-05-05 07:59:52,209 [INFO] >>> diameter(s) =
# 2024-05-05 07:59:52,209 [INFO] [ 58.00 ]
# 2024-05-05 07:59:52,210 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:00:18,481 [INFO] >>>> TOTAL TIME 55.71 sec
# 2024-05-05 08:00:18,818 [INFO] 3%|2         | 91/3080 [2:46:54<70:55:48, 85.43s/it]
# 2024-05-05 08:00:18,831 [INFO] channels set to [0, 0]
# 2024-05-05 08:00:18,831 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:01:15,285 [INFO] estimated cell diameter(s) in 56.45 sec
# 2024-05-05 08:01:15,285 [INFO] >>> diameter(s) =
# 2024-05-05 08:01:15,285 [INFO] [ 23.64 ]
# 2024-05-05 08:01:15,285 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:01:49,293 [INFO] >>>> TOTAL TIME 90.46 sec
# 2024-05-05 08:01:49,632 [INFO] 3%|2         | 92/3080 [2:48:25<72:14:50, 87.04s/it]
# 2024-05-05 08:01:49,646 [INFO] channels set to [0, 0]
# 2024-05-05 08:01:49,647 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:03:12,375 [INFO] estimated cell diameter(s) in 82.73 sec
# 2024-05-05 08:03:12,375 [INFO] >>> diameter(s) =
# 2024-05-05 08:03:12,375 [INFO] [ 15.51 ]
# 2024-05-05 08:03:12,376 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:04:12,185 [INFO] >>>> TOTAL TIME 142.54 sec
# 2024-05-05 08:04:12,481 [INFO] 3%|3         | 93/3080 [2:50:48<86:06:48, 103.79s/it]
# 2024-05-05 08:04:12,504 [INFO] channels set to [0, 0]
# 2024-05-05 08:04:12,505 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:05:24,159 [INFO] estimated cell diameter(s) in 71.65 sec
# 2024-05-05 08:05:24,160 [INFO] >>> diameter(s) =
# 2024-05-05 08:05:24,160 [INFO] [ 14.05 ]
# 2024-05-05 08:05:24,160 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:06:33,091 [INFO] >>>> TOTAL TIME 140.59 sec
# 2024-05-05 08:06:33,387 [INFO] 3%|3         | 94/3080 [2:53:09<95:19:17, 114.92s/it]
# 2024-05-05 08:06:33,403 [INFO] channels set to [0, 0]
# 2024-05-05 08:06:33,404 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:07:11,813 [INFO] estimated cell diameter(s) in 38.41 sec
# 2024-05-05 08:07:11,813 [INFO] >>> diameter(s) =
# 2024-05-05 08:07:11,813 [INFO] [ 34.05 ]
# 2024-05-05 08:07:11,813 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:07:32,004 [INFO] >>>> TOTAL TIME 58.60 sec
# 2024-05-05 08:07:32,331 [INFO] 3%|3         | 95/3080 [2:54:08<81:21:53, 98.13s/it]
# 2024-05-05 08:07:32,346 [INFO] channels set to [0, 0]
# 2024-05-05 08:07:32,346 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:08:02,354 [INFO] estimated cell diameter(s) in 30.01 sec
# 2024-05-05 08:08:02,355 [INFO] >>> diameter(s) =
# 2024-05-05 08:08:02,355 [INFO] [ 59.78 ]
# 2024-05-05 08:08:02,355 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:08:22,813 [INFO] >>>> TOTAL TIME 50.47 sec
# 2024-05-05 08:08:23,366 [INFO] 3%|3         | 96/3080 [2:54:59<69:37:37, 84.00s/it]
# 2024-05-05 08:08:23,379 [INFO] channels set to [0, 0]
# 2024-05-05 08:08:23,379 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:09:31,425 [INFO] estimated cell diameter(s) in 68.05 sec
# 2024-05-05 08:09:31,425 [INFO] >>> diameter(s) =
# 2024-05-05 08:09:31,425 [INFO] [ 11.99 ]
# 2024-05-05 08:09:31,426 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:11:02,581 [INFO] >>>> TOTAL TIME 159.20 sec
# 2024-05-05 08:11:02,912 [INFO] 3%|3         | 97/3080 [2:57:38<88:22:59, 106.66s/it]
# 2024-05-05 08:11:02,939 [INFO] channels set to [0, 0]
# 2024-05-05 08:11:02,939 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:12:35,021 [INFO] estimated cell diameter(s) in 92.08 sec
# 2024-05-05 08:12:35,022 [INFO] >>> diameter(s) =
# 2024-05-05 08:12:35,022 [INFO] [ 14.45 ]
# 2024-05-05 08:12:35,022 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:13:42,929 [INFO] >>>> TOTAL TIME 159.99 sec
# 2024-05-05 08:13:43,240 [INFO] 3%|3         | 98/3080 [3:00:19<101:41:20, 122.76s/it]
# 2024-05-05 08:13:43,253 [INFO] channels set to [0, 0]
# 2024-05-05 08:13:43,254 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 08:15:09,232 [INFO] estimated cell diameter(s) in 85.98 sec
# 2024-05-05 08:15:09,232 [INFO] >>> diameter(s) =
# 2024-05-05 08:15:09,232 [INFO] [ 9.20 ]
# 2024-05-05 08:15:09,232 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 08:17:15,425 [INFO] >>>> TOTAL TIME 212.17 sec
# ...
# 2024-05-05 13:57:28,892 [INFO] >>>> TOTAL TIME 164.08 sec
# 2024-05-05 13:57:29,264 [INFO] 8%|8         | 254/3080 [8:44:05<107:22:19, 136.78s/it]
# 2024-05-05 13:57:29,278 [INFO] channels set to [0, 0]
# 2024-05-05 13:57:29,278 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 13:58:13,483 [INFO] estimated cell diameter(s) in 44.21 sec
# 2024-05-05 13:58:13,483 [INFO] >>> diameter(s) =
# 2024-05-05 13:58:13,483 [INFO] [ 19.42 ]
# 2024-05-05 13:58:13,483 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 13:58:53,436 [INFO] >>>> TOTAL TIME 84.16 sec
# 2024-05-05 13:58:53,831 [INFO] 8%|8         | 255/3080 [8:45:29<95:02:32, 121.12s/it]
# 2024-05-05 13:58:53,863 [INFO] channels set to [0, 0]
# 2024-05-05 13:58:53,863 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 13:59:33,033 [INFO] estimated cell diameter(s) in 39.17 sec
# 2024-05-05 13:59:33,034 [INFO] >>> diameter(s) =
# 2024-05-05 13:59:33,034 [INFO] [ 24.23 ]
# 2024-05-05 13:59:33,034 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:00:04,457 [INFO] >>>> TOTAL TIME 70.59 sec
# 2024-05-05 14:00:04,745 [INFO] 8%|8         | 256/3080 [8:46:40<83:11:40, 106.06s/it]
# 2024-05-05 14:00:04,763 [INFO] channels set to [0, 0]
# 2024-05-05 14:00:04,764 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:00:49,137 [INFO] estimated cell diameter(s) in 44.37 sec
# 2024-05-05 14:00:49,137 [INFO] >>> diameter(s) =
# 2024-05-05 14:00:49,137 [INFO] [ 16.55 ]
# 2024-05-05 14:00:49,137 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:01:44,943 [INFO] >>>> TOTAL TIME 100.18 sec
# 2024-05-05 14:01:45,251 [INFO] 8%|8         | 257/3080 [8:48:21<81:51:34, 104.39s/it]
# 2024-05-05 14:01:45,267 [INFO] channels set to [0, 0]
# 2024-05-05 14:01:45,267 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:02:49,769 [INFO] estimated cell diameter(s) in 64.50 sec
# 2024-05-05 14:02:49,769 [INFO] >>> diameter(s) =
# 2024-05-05 14:02:49,769 [INFO] [ 13.11 ]
# 2024-05-05 14:02:49,769 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:04:16,690 [INFO] >>>> TOTAL TIME 151.42 sec
# 2024-05-05 14:04:17,089 [INFO] 8%|8         | 258/3080 [8:50:53<92:59:18, 118.62s/it]
# 2024-05-05 14:04:17,102 [INFO] channels set to [0, 0]
# 2024-05-05 14:04:17,103 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:05:19,780 [INFO] estimated cell diameter(s) in 62.68 sec
# 2024-05-05 14:05:19,781 [INFO] >>> diameter(s) =
# 2024-05-05 14:05:19,781 [INFO] [ 11.89 ]
# 2024-05-05 14:05:19,781 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:07:02,114 [INFO] >>>> TOTAL TIME 165.01 sec
# 2024-05-05 14:07:02,471 [INFO] 8%|8         | 259/3080 [8:53:38<103:56:51, 132.65s/it]
# 2024-05-05 14:07:02,486 [INFO] channels set to [0, 0]
# 2024-05-05 14:07:02,486 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:07:47,303 [INFO] estimated cell diameter(s) in 44.82 sec
# 2024-05-05 14:07:47,304 [INFO] >>> diameter(s) =
# 2024-05-05 14:07:47,304 [INFO] [ 23.34 ]
# 2024-05-05 14:07:47,304 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:08:17,686 [INFO] >>>> TOTAL TIME 75.20 sec
# 2024-05-05 14:08:18,000 [INFO] 8%|8         | 260/3080 [8:54:54<90:29:12, 115.52s/it]
# 2024-05-05 14:08:18,018 [INFO] channels set to [0, 0]
# 2024-05-05 14:08:18,018 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:08:49,367 [INFO] estimated cell diameter(s) in 31.35 sec
# 2024-05-05 14:08:49,367 [INFO] >>> diameter(s) =
# 2024-05-05 14:08:49,367 [INFO] [ 59.24 ]
# 2024-05-05 14:08:49,367 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:09:11,261 [INFO] >>>> TOTAL TIME 53.24 sec
# 2024-05-05 14:09:11,558 [INFO] 8%|8         | 261/3080 [8:55:47<75:53:59, 96.93s/it]
# 2024-05-05 14:09:11,573 [INFO] channels set to [0, 0]
# 2024-05-05 14:09:11,573 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:10:15,917 [INFO] estimated cell diameter(s) in 64.34 sec
# 2024-05-05 14:10:15,917 [INFO] >>> diameter(s) =
# 2024-05-05 14:10:15,917 [INFO] [ 11.89 ]
# 2024-05-05 14:10:15,917 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:11:41,626 [INFO] >>>> TOTAL TIME 150.05 sec
# 2024-05-05 14:11:41,941 [INFO] 9%|8         | 262/3080 [8:58:18<88:25:34, 112.96s/it]
# 2024-05-05 14:11:41,957 [INFO] channels set to [0, 0]
# 2024-05-05 14:11:41,958 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:13:02,501 [INFO] estimated cell diameter(s) in 80.54 sec
# 2024-05-05 14:13:02,501 [INFO] >>> diameter(s) =
# 2024-05-05 14:13:02,501 [INFO] [ 15.73 ]
# 2024-05-05 14:13:02,501 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:13:58,753 [INFO] >>>> TOTAL TIME 136.80 sec
# 2024-05-05 14:13:59,133 [INFO] 9%|8         | 263/3080 [9:00:35<94:04:56, 120.23s/it]
# 2024-05-05 14:13:59,149 [INFO] channels set to [0, 0]
# 2024-05-05 14:13:59,149 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:15:20,554 [INFO] estimated cell diameter(s) in 81.40 sec
# 2024-05-05 14:15:20,554 [INFO] >>> diameter(s) =
# 2024-05-05 14:15:20,554 [INFO] [ 7.48 ]
# 2024-05-05 14:15:20,554 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:18:25,494 [INFO] >>>> TOTAL TIME 266.35 sec
# 2024-05-05 14:18:26,074 [INFO] 9%|8         | 264/3080 [9:05:02<128:28:34, 164.25s/it]
# 2024-05-05 14:18:26,103 [INFO] channels set to [0, 0]
# 2024-05-05 14:18:26,103 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:19:12,014 [INFO] estimated cell diameter(s) in 45.91 sec
# 2024-05-05 14:19:12,014 [INFO] >>> diameter(s) =
# 2024-05-05 14:19:12,014 [INFO] [ 24.11 ]
# 2024-05-05 14:19:12,014 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:19:40,707 [INFO] >>>> TOTAL TIME 74.60 sec
# 2024-05-05 14:19:41,265 [INFO] 9%|8         | 265/3080 [9:06:17<107:32:23, 137.53s/it]
# 2024-05-05 14:19:41,280 [INFO] channels set to [0, 0]
# 2024-05-05 14:19:41,280 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:20:14,834 [INFO] estimated cell diameter(s) in 33.55 sec
# 2024-05-05 14:20:14,834 [INFO] >>> diameter(s) =
# 2024-05-05 14:20:14,834 [INFO] [ 57.37 ]
# 2024-05-05 14:20:14,835 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:20:37,446 [INFO] >>>> TOTAL TIME 56.17 sec
# 2024-05-05 14:20:37,945 [INFO] 9%|8         | 266/3080 [9:07:14<88:32:33, 113.27s/it]
# 2024-05-05 14:20:37,960 [INFO] channels set to [0, 0]
# 2024-05-05 14:20:37,961 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:21:48,799 [INFO] estimated cell diameter(s) in 70.84 sec
# 2024-05-05 14:21:48,799 [INFO] >>> diameter(s) =
# 2024-05-05 14:21:48,799 [INFO] [ 11.28 ]
# 2024-05-05 14:21:48,799 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:23:43,658 [INFO] >>>> TOTAL TIME 185.70 sec
# 2024-05-05 14:23:43,978 [INFO] 9%|8         | 267/3080 [9:10:20<105:34:01, 135.10s/it]
# 2024-05-05 14:23:43,996 [INFO] channels set to [0, 0]
# 2024-05-05 14:23:43,996 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:25:15,861 [INFO] estimated cell diameter(s) in 91.86 sec
# 2024-05-05 14:25:15,861 [INFO] >>> diameter(s) =
# 2024-05-05 14:25:15,861 [INFO] [ 14.67 ]
# 2024-05-05 14:25:15,861 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:26:25,485 [INFO] >>>> TOTAL TIME 161.49 sec
# 2024-05-05 14:26:25,796 [INFO] 9%|8         | 268/3080 [9:13:01<111:47:24, 143.12s/it]
# 2024-05-05 14:26:25,810 [INFO] channels set to [0, 0]
# 2024-05-05 14:26:25,810 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:27:36,289 [INFO] estimated cell diameter(s) in 70.48 sec
# 2024-05-05 14:27:36,289 [INFO] >>> diameter(s) =
# 2024-05-05 14:27:36,289 [INFO] [ 8.92 ]
# 2024-05-05 14:27:36,289 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:29:52,293 [INFO] >>>> TOTAL TIME 206.48 sec
# 2024-05-05 14:29:52,601 [INFO] 9%|8         | 269/3080 [9:16:28<126:40:09, 162.22s/it]
# 2024-05-05 14:29:52,620 [INFO] channels set to [0, 0]
# 2024-05-05 14:29:52,620 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:30:40,836 [INFO] estimated cell diameter(s) in 48.22 sec
# 2024-05-05 14:30:40,836 [INFO] >>> diameter(s) =
# 2024-05-05 14:30:40,836 [INFO] [ 24.95 ]
# 2024-05-05 14:30:40,836 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:31:09,362 [INFO] >>>> TOTAL TIME 76.74 sec
# 2024-05-05 14:31:09,658 [INFO] 9%|8         | 270/3080 [9:17:45<106:40:51, 136.67s/it]
# 2024-05-05 14:31:09,675 [INFO] channels set to [0, 0]
# 2024-05-05 14:31:09,675 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:31:42,813 [INFO] estimated cell diameter(s) in 33.14 sec
# 2024-05-05 14:31:42,813 [INFO] >>> diameter(s) =
# 2024-05-05 14:31:42,813 [INFO] [ 55.74 ]
# 2024-05-05 14:31:42,813 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:32:05,200 [INFO] >>>> TOTAL TIME 55.53 sec
# 2024-05-05 14:32:05,522 [INFO] 9%|8         | 271/3080 [9:18:41<87:43:37, 112.43s/it]
# 2024-05-05 14:32:05,540 [INFO] channels set to [0, 0]
# 2024-05-05 14:32:05,540 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:33:16,640 [INFO] estimated cell diameter(s) in 71.10 sec
# 2024-05-05 14:33:16,640 [INFO] >>> diameter(s) =
# 2024-05-05 14:33:16,640 [INFO] [ 11.67 ]
# 2024-05-05 14:33:16,640 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:34:58,091 [INFO] >>>> TOTAL TIME 172.55 sec
# 2024-05-05 14:34:58,442 [INFO] 9%|8         | 272/3080 [9:21:34<101:51:00, 130.58s/it]
# 2024-05-05 14:34:58,454 [INFO] channels set to [0, 0]
# 2024-05-05 14:34:58,454 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:36:21,036 [INFO] estimated cell diameter(s) in 82.58 sec
# 2024-05-05 14:36:21,036 [INFO] >>> diameter(s) =
# 2024-05-05 14:36:21,036 [INFO] [ 16.55 ]
# 2024-05-05 14:36:21,036 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:37:14,173 [INFO] >>>> TOTAL TIME 135.72 sec
# 2024-05-05 14:37:14,501 [INFO] 9%|8         | 273/3080 [9:23:50<103:05:47, 132.22s/it]
# 2024-05-05 14:37:14,516 [INFO] channels set to [0, 0]
# 2024-05-05 14:37:14,516 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:38:16,193 [INFO] estimated cell diameter(s) in 61.68 sec
# 2024-05-05 14:38:16,193 [INFO] >>> diameter(s) =
# 2024-05-05 14:38:16,193 [INFO] [ 15.05 ]
# 2024-05-05 14:38:16,193 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:39:23,945 [INFO] >>>> TOTAL TIME 129.43 sec
# 2024-05-05 14:39:24,391 [INFO] 9%|8         | 274/3080 [9:26:00<102:30:51, 131.52s/it]
# 2024-05-05 14:39:24,405 [INFO] channels set to [0, 0]
# 2024-05-05 14:39:24,405 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:40:04,789 [INFO] estimated cell diameter(s) in 40.38 sec
# 2024-05-05 14:40:04,789 [INFO] >>> diameter(s) =
# 2024-05-05 14:40:04,789 [INFO] [ 34.63 ]
# 2024-05-05 14:40:04,790 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:40:24,440 [INFO] >>>> TOTAL TIME 60.04 sec
# 2024-05-05 14:40:24,773 [INFO] 9%|8         | 275/3080 [9:27:00<85:50:55, 110.18s/it]
# 2024-05-05 14:40:24,786 [INFO] channels set to [0, 0]
# 2024-05-05 14:40:24,786 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:40:59,722 [INFO] estimated cell diameter(s) in 34.94 sec
# 2024-05-05 14:40:59,723 [INFO] >>> diameter(s) =
# 2024-05-05 14:40:59,723 [INFO] [ 51.31 ]
# 2024-05-05 14:40:59,723 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:41:22,882 [INFO] >>>> TOTAL TIME 58.10 sec
# 2024-05-05 14:41:23,177 [INFO] 9%|8         | 276/3080 [9:27:59<73:43:11, 94.65s/it]
# 2024-05-05 14:41:23,194 [INFO] channels set to [0, 0]
# 2024-05-05 14:41:23,194 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:42:29,703 [INFO] estimated cell diameter(s) in 66.51 sec
# 2024-05-05 14:42:29,703 [INFO] >>> diameter(s) =
# 2024-05-05 14:42:29,703 [INFO] [ 10.55 ]
# 2024-05-05 14:42:29,703 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:44:15,311 [INFO] >>>> TOTAL TIME 172.12 sec
# 2024-05-05 14:44:15,653 [INFO] 9%|8         | 277/3080 [9:30:51<91:52:22, 118.00s/it]
# 2024-05-05 14:44:15,672 [INFO] channels set to [0, 0]
# 2024-05-05 14:44:15,672 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:45:50,892 [INFO] estimated cell diameter(s) in 95.22 sec
# 2024-05-05 14:45:50,892 [INFO] >>> diameter(s) =
# 2024-05-05 14:45:50,892 [INFO] [ 14.63 ]
# 2024-05-05 14:45:50,892 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:46:53,568 [INFO] >>>> TOTAL TIME 157.90 sec
# 2024-05-05 14:46:53,922 [INFO] 9%|9         | 278/3080 [9:33:29<101:14:38, 130.08s/it]
# 2024-05-05 14:46:53,936 [INFO] channels set to [0, 0]
# 2024-05-05 14:46:53,936 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:48:05,825 [INFO] estimated cell diameter(s) in 71.89 sec
# 2024-05-05 14:48:05,826 [INFO] >>> diameter(s) =
# 2024-05-05 14:48:05,826 [INFO] [ 12.77 ]
# 2024-05-05 14:48:05,826 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:49:27,986 [INFO] >>>> TOTAL TIME 154.05 sec
# 2024-05-05 14:49:28,331 [INFO] 9%|9         | 279/3080 [9:36:04<106:53:13, 137.38s/it]
# 2024-05-05 14:49:28,347 [INFO] channels set to [0, 0]
# 2024-05-05 14:49:28,347 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:50:07,210 [INFO] estimated cell diameter(s) in 38.86 sec
# 2024-05-05 14:50:07,210 [INFO] >>> diameter(s) =
# 2024-05-05 14:50:07,210 [INFO] [ 34.18 ]
# 2024-05-05 14:50:07,210 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:50:27,408 [INFO] >>>> TOTAL TIME 59.06 sec
# 2024-05-05 14:50:27,722 [INFO] 9%|9         | 280/3080 [9:37:03<88:39:07, 113.98s/it]
# 2024-05-05 14:50:27,737 [INFO] channels set to [0, 0]
# 2024-05-05 14:50:27,737 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:51:03,257 [INFO] estimated cell diameter(s) in 35.52 sec
# 2024-05-05 14:51:03,257 [INFO] >>> diameter(s) =
# 2024-05-05 14:51:03,257 [INFO] [ 59.29 ]
# 2024-05-05 14:51:03,257 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:51:22,381 [INFO] >>>> TOTAL TIME 54.64 sec
# 2024-05-05 14:51:22,750 [INFO] 9%|9         | 281/3080 [9:37:58<74:52:10, 96.30s/it]
# 2024-05-05 14:51:22,765 [INFO] channels set to [0, 0]
# 2024-05-05 14:51:22,765 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2024-05-05 14:52:30,176 [INFO] estimated cell diameter(s) in 67.41 sec
# 2024-05-05 14:52:30,177 [INFO] >>> diameter(s) =
# 2024-05-05 14:52:30,177 [INFO] [ 10.55 ]
# 2024-05-05 14:52:30,177 [INFO] ~~~ FINDING MASKS ~~~
# 2024-05-05 14:54:13,124 [INFO] >>>> TOTAL TIME 170.36 sec
# 2024-05-05 14:54:13,494 [INFO] 9%|9         | 282/3080 [9:40:49<92:12:06, 118.63s/it]
# 2024-05-05 14:54:13,510 [INFO] channels set to [0, 0]
# 2024-05-05 14:54:13,510 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# ^C
# 2024-05-05 14:55:36,668 [INFO] 9%|9         | 282/3080 [9:42:12<96:16:42, 123.87s/it]
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/__main__.py", line 308, in <module>
#     main()
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/__main__.py", line 182, in main
#     out = model.eval(
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/models.py", line 164, in eval
#     diams, _ = self.sz.eval(x, channels=channels, channel_axis=channel_axis,
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/models.py", line 678, in eval
#     masks = self.cp.eval(
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/models.py", line 410, in eval
#     masks, styles, dP, cellprob, p = self._run_cp(
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/models.py", line 481, in _run_cp
#     yf, style = run_net(self.net, img, bsize=bsize, augment=augment,
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/core.py", line 228, in run_net
#     y, style = _run_tiled(net, imgs, augment=augment, bsize=bsize,
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/core.py", line 318, in _run_tiled
#     y0, style = _forward(net, IMG[irange])
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/core.py", line 176, in _forward
#     y, style = net(X)[:2]
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/resnet_torch.py", line 272, in forward
#     T0 = [t0.to_dense() for t0 in T0]
#   File "/home/vivinglis/.local/lib/python3.8/site-packages/cellpose/resnet_torch.py", line 272, in <listcomp>
#     T0 = [t0.to_dense() for t0 in T0]
# KeyboardInterrupt

# %% [markdown]
# After 9h 40min, had only segmented 9% of the images, since I don't have a GPU on my computer.
# Based on that I decided to only use 220 of the images to test the pipeline: B02*-B23*.
# I created symbolic links to a subset of the images in "~/phenaros/data/images_subset".
# I then divided the masks generated by cellpose into "~/phenaros/cellpose_output/masks" for all B02*-B23* files and to "C_masks" for the additional ones that cellpose managed to generate in the time I gave it to run.

# %% [markdown]
# I also now realise I used the code from the manual for running it in the command line on nuclear data (grayscale) where the diameter is automatically estimated. In hindsight, I would have used this example to run it in the notebook:
# https://cellpose.readthedocs.io/en/latest/notebook.html
#
# **Note**: I'm not sure why I used the nuclei model, probably because it was late and I was tired, but if I could run it again I would've instead used cyto3 since it's the super-generalist model. Should've read the manual more closely!

# %%
# !tree -d ~/phenaros/
# !tree ~/phenaros/data/images_subset
# Out:
# /home/vivinglis/phenaros/
# ├── cellpose_output
# │   ├── C_masks
# │   └── masks
# ├── data
# │   ├── images
# │   └── images_subset
# └── deepprofiler_output
#     ├── inputs
#     │   ├── config
#     │   ├── images
#     │   ├── locations
#     │   ├── metadata
#     │   └── outlines
#     └── outputs
#         ├── compressed
#         │   └── images
#         ├── intensities
#         ├── results
#         │   ├── checkpoint
#         │   ├── features
#         │   ├── logs
#         │   └── summaries
#         └── single-cells
#
# 23 directories
# /home/vivinglis/phenaros/data/images_subset
# ├── B02_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B02_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B02_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B02_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B02_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B02_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B02_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B02_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B02_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B02_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B02_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B02_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B02_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B02_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B02_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B02_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B02_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B02_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B02_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B02_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B02_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B02_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B02_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B02_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B02_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B02_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B02_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B02_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B02_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B02_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B02_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B02_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B02_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B02_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B02_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B02_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B02_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B02_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B02_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B02_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B03_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B03_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B03_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B03_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B03_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B03_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B03_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B03_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B03_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B03_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B03_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B03_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B03_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B03_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B03_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B03_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B03_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B03_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B03_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B03_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B03_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B03_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B03_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B03_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B03_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B03_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B03_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B03_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B03_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B03_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B03_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B03_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B03_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B03_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B03_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B03_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B03_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B03_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B03_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B03_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B04_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B04_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B04_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B04_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B04_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B04_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B04_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B04_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B04_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B04_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B04_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B04_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B04_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B04_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B04_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B04_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B04_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B04_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B04_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B04_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B04_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B04_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B04_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B04_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B04_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B04_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B04_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B04_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B04_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B04_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B04_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B04_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B04_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B04_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B04_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B04_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B04_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B04_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B04_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B04_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B05_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B05_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B05_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B05_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B05_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B05_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B05_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B05_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B05_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B05_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B05_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B05_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B05_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B05_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B05_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B05_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B05_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B05_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B05_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B05_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B05_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B05_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B05_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B05_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B05_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B05_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B05_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B05_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B05_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B05_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B05_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B05_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B05_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B05_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B05_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B05_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B05_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B05_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B05_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B05_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B06_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B06_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B06_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B06_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B06_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B06_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B06_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B06_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B06_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B06_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B06_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B06_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B06_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B06_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B06_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B06_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B06_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B06_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B06_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B06_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B06_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B06_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B06_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B06_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B06_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B06_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B06_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B06_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B06_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B06_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B06_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B06_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B06_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B06_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B06_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B06_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B06_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B06_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B06_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B06_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B07_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B07_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B07_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B07_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B07_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B07_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B07_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B07_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B07_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B07_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B07_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B07_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B07_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B07_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B07_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B07_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B07_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B07_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B07_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B07_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B07_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B07_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B07_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B07_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B07_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B07_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B07_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B07_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B07_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B07_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B07_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B07_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B07_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B07_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B07_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B07_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B07_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B07_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B07_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B07_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B08_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B08_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B08_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B08_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B08_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B08_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B08_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B08_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B08_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B08_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B08_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B08_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B08_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B08_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B08_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B08_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B08_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B08_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B08_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B08_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B08_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B08_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B08_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B08_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B08_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B08_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B08_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B08_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B08_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B08_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B08_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B08_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B08_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B08_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B08_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B08_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B08_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B08_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B08_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B08_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B09_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B09_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B09_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B09_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B09_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B09_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B09_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B09_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B09_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B09_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B09_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B09_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B09_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B09_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B09_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B09_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B09_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B09_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B09_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B09_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B09_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B09_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B09_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B09_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B09_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B09_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B09_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B09_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B09_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B09_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B09_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B09_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B09_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B09_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B09_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B09_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B09_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B09_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B09_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B09_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B10_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B10_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B10_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B10_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B10_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B10_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B10_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B10_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B10_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B10_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B10_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B10_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B10_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B10_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B10_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B10_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B10_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B10_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B10_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B10_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B10_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B10_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B10_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B10_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B10_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B10_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B10_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B10_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B10_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B10_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B10_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B10_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B10_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B10_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B10_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B10_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B10_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B10_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B10_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B10_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B11_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B11_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B11_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B11_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B11_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B11_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B11_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B11_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B11_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B11_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B11_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B11_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B11_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B11_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B11_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B11_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B11_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B11_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B11_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B11_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B11_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B11_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B11_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B11_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B11_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B11_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B11_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B11_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B11_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B11_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B11_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B11_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B11_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B11_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B11_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B11_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B11_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B11_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B11_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B11_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B12_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B12_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B12_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B12_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B12_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B12_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B12_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B12_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B12_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B12_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B12_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B12_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B12_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B12_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B12_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B12_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B12_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B12_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B12_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B12_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B12_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B12_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B12_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B12_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B12_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B12_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B12_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B12_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B12_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B12_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B12_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B12_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B12_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B12_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B12_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B12_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B12_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B12_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B12_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B12_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B13_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B13_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B13_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B13_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B13_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B13_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B13_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B13_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B13_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B13_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B13_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B13_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B13_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B13_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B13_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B13_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B13_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B13_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B13_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B13_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B13_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B13_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B13_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B13_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B13_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B13_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B13_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B13_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B13_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B13_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B13_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B13_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B13_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B13_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B13_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B13_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B13_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B13_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B13_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B13_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B14_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B14_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B14_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B14_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B14_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B14_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B14_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B14_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B14_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B14_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B14_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B14_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B14_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B14_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B14_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B14_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B14_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B14_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B14_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B14_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B14_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B14_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B14_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B14_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B14_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B14_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B14_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B14_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B14_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B14_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B14_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B14_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B14_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B14_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B14_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B14_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B14_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B14_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B14_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B14_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B15_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B15_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B15_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B15_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B15_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B15_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B15_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B15_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B15_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B15_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B15_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B15_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B15_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B15_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B15_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B15_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B15_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B15_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B15_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B15_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B15_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B15_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B15_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B15_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B15_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B15_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B15_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B15_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B15_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B15_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B15_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B15_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B15_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B15_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B15_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B15_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B15_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B15_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B15_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B15_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B16_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B16_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B16_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B16_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B16_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B16_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B16_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B16_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B16_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B16_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B16_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B16_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B16_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B16_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B16_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B16_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B16_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B16_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B16_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B16_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B16_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B16_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B16_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B16_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B16_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B16_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B16_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B16_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B16_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B16_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B16_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B16_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B16_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B16_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B16_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B16_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B16_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B16_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B16_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B16_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B17_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B17_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B17_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B17_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B17_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B17_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B17_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B17_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B17_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B17_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B17_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B17_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B17_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B17_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B17_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B17_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B17_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B17_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B17_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B17_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B17_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B17_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B17_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B17_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B17_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B17_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B17_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B17_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B17_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B17_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B17_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B17_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B17_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B17_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B17_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B17_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B17_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B17_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B17_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B17_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B18_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B18_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B18_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B18_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B18_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B18_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B18_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B18_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B18_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B18_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B18_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B18_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B18_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B18_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B18_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B18_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B18_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B18_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B18_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B18_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B18_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B18_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B18_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B18_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B18_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B18_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B18_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B18_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B18_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B18_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B18_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B18_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B18_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B18_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B18_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B18_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B18_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B18_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B18_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B18_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B19_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B19_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B19_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B19_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B19_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B19_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B19_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B19_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B19_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B19_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B19_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B19_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B19_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B19_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B19_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B19_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B19_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B19_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B19_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B19_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B19_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B19_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B19_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B19_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B19_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B19_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B19_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B19_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B19_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B19_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B19_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B19_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B19_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B19_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B19_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B19_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B19_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B19_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B19_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B19_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B20_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B20_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B20_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B20_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B20_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B20_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B20_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B20_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B20_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B20_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B20_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B20_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B20_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B20_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B20_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B20_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B20_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B20_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B20_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B20_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B20_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B20_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B20_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B20_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B20_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B20_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B20_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B20_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B20_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B20_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B20_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B20_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B20_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B20_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B20_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B20_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B20_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B20_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B20_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B20_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B21_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B21_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B21_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B21_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B21_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B21_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B21_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B21_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B21_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B21_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B21_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B21_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B21_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B21_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B21_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B21_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B21_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B21_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B21_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B21_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B21_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B21_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B21_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B21_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B21_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B21_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B21_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B21_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B21_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B21_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B21_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B21_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B21_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B21_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B21_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B21_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B21_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B21_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B21_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B21_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B22_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B22_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B22_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B22_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B22_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B22_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B22_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B22_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B22_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B22_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B22_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B22_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B22_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B22_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B22_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B22_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B22_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B22_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B22_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B22_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B22_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B22_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B22_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B22_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B22_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B22_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B22_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B22_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B22_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B22_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B22_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B22_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B22_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B22_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B22_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B22_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B22_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B22_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# ├── B22_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B22_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B23_s1_x0_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B23_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
# ├── B23_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B23_s1_x0_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B23_s1_x0_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B23_s1_x0_y0_Fluorescence_488_nm_Ex.tiff
# ├── B23_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B23_s1_x0_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B23_s1_x0_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B23_s1_x0_y0_Fluorescence_561_nm_Ex.tiff
# ├── B23_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B23_s1_x0_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B23_s1_x0_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B23_s1_x0_y0_Fluorescence_638_nm_Ex.tiff
# ├── B23_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B23_s1_x0_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B23_s1_x0_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B23_s1_x0_y0_Fluorescence_730_nm_Ex.tiff
# ├── B23_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B23_s1_x0_y0_Fluorescence_730_nm_Ex_seg.npy
# ├── B23_s2_x1_y0_Fluorescence_405_nm_Ex.tiff -> ../images/B23_s2_x1_y0_Fluorescence_405_nm_Ex.tiff
# ├── B23_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy -> ../images/B23_s2_x1_y0_Fluorescence_405_nm_Ex_seg.npy
# ├── B23_s2_x1_y0_Fluorescence_488_nm_Ex.tiff -> ../images/B23_s2_x1_y0_Fluorescence_488_nm_Ex.tiff
# ├── B23_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy -> ../images/B23_s2_x1_y0_Fluorescence_488_nm_Ex_seg.npy
# ├── B23_s2_x1_y0_Fluorescence_561_nm_Ex.tiff -> ../images/B23_s2_x1_y0_Fluorescence_561_nm_Ex.tiff
# ├── B23_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy -> ../images/B23_s2_x1_y0_Fluorescence_561_nm_Ex_seg.npy
# ├── B23_s2_x1_y0_Fluorescence_638_nm_Ex.tiff -> ../images/B23_s2_x1_y0_Fluorescence_638_nm_Ex.tiff
# ├── B23_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy -> ../images/B23_s2_x1_y0_Fluorescence_638_nm_Ex_seg.npy
# ├── B23_s2_x1_y0_Fluorescence_730_nm_Ex.tiff -> ../images/B23_s2_x1_y0_Fluorescence_730_nm_Ex.tiff
# └── B23_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy -> ../images/B23_s2_x1_y0_Fluorescence_730_nm_Ex_seg.npy
#
# 0 directories, 440 files

# %% [markdown]
# ## Calculate Location using CellProfiler

# %% [markdown]
# Since DeepProfiler requires the cell locations, I would then run CellProfiler and store them as directed by the DeepProfiler manual.
#
# https://cytomining.github.io/DeepProfiler-handbook/docs/04-metadata.html#single-cell-locations-file

# %% [markdown]
# ### Extract Features with CellProfiler?
#
# Didn't get a chance to run this, and couldn't really establish it from the brief read of the manual, but I assume that Cellprofiler may be able to extract the features such as:
#
# 1. DNA (Nucleus)
# 2. RNA (Nucleoli, cytoplasmic RNA)
# 3. ER (Endoplasmic reticulum)
# 4. AGP (F-actin cytoskeleton, Golgi, plasma membrane)
# 5. Mito (Mitochondria)
#
# These would later be used to run the Cell Painting CNN model in DeepProfiler.

# %% [markdown]
# ## Profiles using DeepProfiler

# %%
# Install DeepProfiler in command line
# !git clone https://github.com/broadinstitute/DeepProfiler.git
# !cd ~/DeepProfiler/
# !pip install -e .

# %%
# %cd ~/DeepProfiler
# !python3.8 deepprofiler --root=/home/vivinglis/phenaros/deepprofiler_output setup
# Out:
# /home/vivinglis/DeepProfiler
# 2024-05-05 15:39:31.587106: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-05-05 15:39:31.587168: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/vivinglis/.local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2024-05-05 15:39:33,078 - WARNING - From /home/vivinglis/.local/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/inputs/locations/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/inputs/config/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/inputs/images/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/inputs/metadata/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/intensities/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/compressed/images/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/single-cells/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/results/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/results/checkpoint/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/results/logs/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/results/summaries/
# Directory exists:  /home/vivinglis/phenaros/deepprofiler_output/outputs/results/features/
# /home/vivinglis/phenaros/deepprofiler_output

# %%
# %cd ~/phenaros/
# !tree deepprofiler_output
# Out:
# /home/vivinglis/phenaros
# deepprofiler_output
# ├── inputs
# │   ├── config
# │   ├── images
# │   ├── locations
# │   └── metadata
# └── outputs
#     ├── compressed
#     │   └── images
#     ├── intensities
#     ├── results
#     │   ├── checkpoint
#     │   ├── features
#     │   ├── logs
#     │   └── summaries
#     └── single-cells
#
# 15 directories, 0 files

# %% [markdown]
# ### Preparing Metadata File
#
# Since the cells have already been masked with Cellpose, the next step would be to prepare the metadata file for DeepProfiler and place it in the inputs/metadata/ directory.
#
# *On the topic of masks* - DeepProfiler reccommends not using them for Cell Painting CNN model, so I would want to investigate that further to figure out what they mean.
#
# The metadata file would be called "index.csv" and would contain the following columns:
# Metadata_Plate, Metadata_Well, Metadata_Site, Channel_Name, Treatment and Replicate.
#
# The well and site can be extracted from the image file names, e.g. for image file "B23_s2_x1_y0_Fluorescence_730_nm_Ex.tiff" the well is B23 and the site is s2. From the file names, it seems as if there are 2 sites per well.
#
# However, the filenames for the images don't indicate which plate they belong to. According to DeepProfiler, it is expected that the images are in a folder named after the plate, but here they are just in an "images" directory, e.g.:
# data/images/B02_s1_x0_y0_Fluorescence_405_nm_Ex.tiff
#
# According to the metadata file (provided both in parquet and csv format on the GitHub page), the B02 well may belong to 1 of 4 different plates. Assuming the image files have been stored in deepprofiler_output/inputs/images, the metadata file would look something like this:
#
# | Metadata_Plate | Metadata_Well | Metadata_Site | Channel_Name                                              | Treatment          | Replicate |
# |----------------|---------------|---------------|-----------------------------------------------------------|--------------------|-----------|
# | PB000103       | B02           | 1             | PB000100/B02_s1_x0_y0_Fluorescence_405_nm_Ex_cp_masks.png | negcon | 1         |
#
# In the metadata it seems there are two treatment types - poscon and negcon, and two of each of these types.
# If these are then considered replicates of the treatment types then it could be something like this:
#
# | Treatment | Batch_ID           | Replicate |
# |-----------|--------------------|-----------|
# | poscon    | Etoposide          | 1         |
# | poscon    | Paclitaxel         | 2         |
# | negcon    | Dimethyl Sulfoxide | 1         |
# | negcon    | D-Sorbitol         | 2         |

# %% [markdown]
# ### Configuration File
#
# The next step would be to prepare the configuration filer for DeepProfiler according to the below:
#
# https://cytomining.github.io/DeepProfiler-handbook/docs/05-config.html#configuration-file-organization
#
# And finally to run profiling using the CNN Cell Painting model:
#
# https://cytomining.github.io/DeepProfiler-handbook/docs/06-profiling.html#profiling-with-cell-painting-cnn-model

# %% [markdown]
# ## Aggregate and Visualise
#
# Using the Downstream Analysis page on the DeepProfiler page, I would aggregate the data and visualise it using UMAP.
#
# https://cytomining.github.io/DeepProfiler-handbook/docs/08-process.html#downstream-analysis

# %% [markdown]
# ## Conclusions
#
# Just reading through everything I did, I've noticed a lot of mistakes that I would want to go back and investigate further.
# For example, setting up individual docker containers for each analysis tool to avoid conflicting dependencies, running the cyto3 model instead during the Cellpose step, figuring out what to do with the masks during the Cell Painting CNN step and reading all the manuals much more closely.
#
# If I had time I would overhaul it all and start from the beginning now that I have a better understanding of each of the individual steps.
#
#
#
# ... Oh and I would become a PC gamer so that I would have had access to an NVIDIA graphics card.
